# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthikk0844/GENERATIVE-AI/blob/main/2303A52202_week2_ASS2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Develop mathematical modeling for the given case study and find solution using Python![Screenshot 2025-01-22 144045.png](data:image/png;base64,...)

# %%
from scipy.optimize import linprog
c = [-6, -5]
A = [[1, 1], [3, 2]]
b = [5, 12]
x_bounds = (0, None)
y_bounds = (0, None)
result = linprog(c, A_ub=A, b_ub=b, bounds=[x_bounds, y_bounds], method='highs')
if result.success:
    print(f"Optimal number of units of A (x): {result.x[0]}")
    print(f"Optimal number of units of B (y): {result.x[1]}")
    print(f"Maximum profit: Rs {-result.fun}")
else:
    print("No solution found.")
# Out:
# Optimal number of units of A (x): 2.0
# Optimal number of units of B (y): 3.0
# Maximum profit: Rs 27.0

# %% [markdown]
# 2) Develop mathematical modeling for the given case study and find solution using Python![Screenshot 2025-01-22 143034.png](data:image/png;base64,...)

# %%
from scipy.optimize import linprog
profit_per_hectare = [-50, -120]
constraints = [
    [7000, 2000],
    [10, 30],
    [1, 1]
]
bounds = [700000, 1200, 110]
x_bounds = (0, None)
y_bounds = (0, None)
result = linprog(
    c=profit_per_hectare,
    A_ub=constraints,
    b_ub=bounds,
    bounds=[x_bounds, y_bounds],
    method='highs'
)
if result.success:
    optimal_wheat = result.x[0]
    optimal_barley = result.x[1]
    optimal_profit = -result.fun
    print("Optimal Solution:")
    print(f"Wheat: {optimal_wheat:.2f} hectares")
    print(f"Barley: {optimal_barley:.2f} hectares")
    print(f"Maximum Profit: Rs. {optimal_profit:.2f}")
else:
    print("Optimization failed:", result.message)
# Out:
# Optimal Solution:
# Wheat: 97.89 hectares
# Barley: 7.37 hectares
# Maximum Profit: Rs. 5778.95
